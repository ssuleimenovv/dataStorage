# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка датасета
file_path = 'appearances.csv'
df = pd.read_csv(file_path)

# Первичный анализ данных
print("Первые строки датасета:")
print(df.head())
print("\nИнформация о датасете:")
print(df.info())
print("\nОсновные статистические характеристики:")
print(df.describe())

# Проверка на пропущенные значения
print("\nПропущенные значения:")
print(df.isnull().sum())

# Обработка пропущенных значений
# Пример: замена NaN на медиану в числовых столбцах
df.fillna(df.median(numeric_only=True), inplace=True)

# Выявление выбросов с помощью boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.select_dtypes(include=[np.number]))
plt.title('Boxplot для поиска выбросов')
plt.show()

# Пример: удаление выбросов по межквартильному размаху
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df_clean = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

print(f"Размер данных после удаления выбросов: {df_clean.shape}")

# Создание новых переменных (пример)
# df_clean['new_feature'] = df_clean['existing_feature'] * 2

# Анализ ключевых трендов и статистик
print("\nКорреляционная матрица:")
correlation_matrix = df_clean.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Тепловая карта корреляции')
plt.show()

# Визуализации
plt.figure(figsize=(10, 6))
sns.histplot(df_clean.select_dtypes(include=[np.number]).iloc[:, 0], kde=True)
plt.title('Распределение первого числового признака')
plt.show()

# Вывод рекомендаций на основе анализа
# Здесь можно добавить анализ трендов, паттернов и выводы для бизнеса или практики

print("Анализ завершён! Добавьте интерпретации и рекомендации по результатам.")

# Сохранение очищенного датасета
output_path = 'cleaned_appearances.csv'
df_clean.to_csv(output_path, index=False)
print(f"Очищенный датасет сохранён как {output_path}")

# Готово! 🚀

# %%
file_path = 'appearances.csv'
df = pd.read_csv(file_path)

# Первичный анализ данных
print("Первые строки датасета:")
print(df.head())
print("\nИнформация о датасете:")
print(df.info())
print("\nОсновные статистические характеристики:")
print(df.describe())

# Проверка на пропущенные значения
print("\nПропущенные значения:")
print(df.isnull().sum())

# Обработка пропущенных значений
# Пример: замена NaN на медиану в числовых столбцах
df.fillna(df.median(numeric_only=True), inplace=True)

# Выявление выбросов с помощью boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df.select_dtypes(include=[np.number]))
plt.title('Boxplot для поиска выбросов')
plt.show()

# Пример: удаление выбросов по межквартильному размаху
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df_clean = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

print(f"Размер данных после удаления выбросов: {df_clean.shape}")

# Создание новых переменных (пример)
# df_clean['new_feature'] = df_clean['existing_feature'] * 2

# Анализ ключевых трендов и статистик
print("\nКорреляционная матрица:")
correlation_matrix = df_clean.corr()
print(correlation_matrix)

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Тепловая карта корреляции')
plt.show()

# Визуализации
plt.figure(figsize=(10, 6))
sns.histplot(df_clean.select_dtypes(include=[np.number]).iloc[:, 0], kde=True)
plt.title('Распределение первого числового признака')
plt.show()

# Вывод рекомендаций на основе анализа
# Здесь можно добавить анализ трендов, паттернов и выводы для бизнеса или практики

print("Анализ завершён! Добавьте интерпретации и рекомендации по результатам.")

# Сохранение очищенного датасета
output_path = 'cleaned_appearances.csv'
df_clean.to_csv(output_path, index=False)
print(f"Очищенный датасет сохранён как {output_path}")

# Готово! 🚀
